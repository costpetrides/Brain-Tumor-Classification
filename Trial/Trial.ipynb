# %% [markdown]
# <a href="https://colab.research.google.com/github/costpetrides/Brain-Tumor-Classification/blob/main/Trial/Trial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Giloma

# %% [markdown]
# ![giloma2 6.49.57 PM.jpg](data:image/jpeg;base64,...)

# %%
from tensorflow.keras.models import load_model
import numpy as np
from tensorflow import keras
from PIL import Image

model = load_model('/content/BrainTumor_1.h5')

image_path = '/content/giloma.jpg'   # Doctors said that was minigioma :(
new_image = Image.open(image_path)
new_image = new_image.resize((180, 180))
new_image = new_image.convert('RGB')  # Convert to RGB format
new_image = np.array(new_image) / 255.0

# Make a prediction
predicted_probabilities = model.predict(np.expand_dims(new_image, axis=0))

predicted_class = np.argmax(predicted_probabilities)

class_labels = ['giloma', 'meningioma', 'notumor', 'pituitary']

predicted_label = class_labels[predicted_class]

print(f"Predicted Class: {predicted_label}")
print(f"Class Probabilities: {predicted_probabilities}")
# Out:
# 1/1 [==============================] - 0s 104ms/step
# Predicted Class: giloma
# Class Probabilities: [[0.58842856 0.229238   0.00592816 0.17640525]]

# %%
from tensorflow.keras.models import load_model
import numpy as np
from tensorflow import keras
from PIL import Image

model = load_model('/content/BrainTumor_2.h5')

image_path = '/content/giloma.jpg'   # Doctors said that was minigioma :(
new_image = Image.open(image_path)
new_image = new_image.resize((180, 180))
new_image = new_image.convert('RGB')  # Convert to RGB format
new_image = np.array(new_image) / 255.0

# Make a prediction
predicted_probabilities = model.predict(np.expand_dims(new_image, axis=0))

predicted_class = np.argmax(predicted_probabilities)

class_labels = ['giloma', 'meningioma', 'notumor', 'pituitary']

predicted_label = class_labels[predicted_class]

print(f"Predicted Class: {predicted_label}")
print(f"Class Probabilities: {predicted_probabilities}")
# Out:
# 1/1 [==============================] - 0s 96ms/step
# Predicted Class: giloma
# Class Probabilities: [[0.58842856 0.229238   0.00592816 0.17640525]]

# %% [markdown]
# ---

# %% [markdown]
# ![giloma 6.49.57 PM.jpg](data:image/jpeg;base64,...)

# %%
from tensorflow.keras.models import load_model
import numpy as np
from tensorflow import keras
from PIL import Image

model = load_model('/content/BrainTumor_1.h5')

image_path = '/content/giloma2.jpg'   # Doctors said that was minigioma :(
new_image = Image.open(image_path)
new_image = new_image.resize((180, 180))
new_image = new_image.convert('RGB')  # Convert to RGB format
new_image = np.array(new_image) / 255.0

# Make a prediction
predicted_probabilities = model.predict(np.expand_dims(new_image, axis=0))

predicted_class = np.argmax(predicted_probabilities)

class_labels = ['giloma', 'meningioma', 'notumor', 'pituitary']

predicted_label = class_labels[predicted_class]

print(f"Predicted Class: {predicted_label}")
print(f"Class Probabilities: {predicted_probabilities}")
# Out:
# 1/1 [==============================] - 0s 99ms/step
# Predicted Class: meningioma
# Class Probabilities: [[0.31683376 0.6774171  0.00491838 0.00083075]]

# %%
from tensorflow.keras.models import load_model
import numpy as np
from tensorflow import keras
from PIL import Image

model = load_model('/content/BrainTumor_2.h5')

image_path = '/content/giloma2.jpg'   # Doctors said that was minigioma :(
new_image = Image.open(image_path)
new_image = new_image.resize((180, 180))
new_image = new_image.convert('RGB')  # Convert to RGB format
new_image = np.array(new_image) / 255.0

# Make a prediction
predicted_probabilities = model.predict(np.expand_dims(new_image, axis=0))

predicted_class = np.argmax(predicted_probabilities)

class_labels = ['giloma', 'meningioma', 'notumor', 'pituitary']

predicted_label = class_labels[predicted_class]

print(f"Predicted Class: {predicted_label}")
print(f"Class Probabilities: {predicted_probabilities}")
# Out:
# 1/1 [==============================] - 0s 275ms/step
# Predicted Class: meningioma
# Class Probabilities: [[0.31683376 0.6774171  0.00491838 0.00083075]]

# %% [markdown]
# # Menigioma

# %% [markdown]
# ![minigioma.jpg](data:image/jpeg;base64,...)

# %%
from tensorflow.keras.models import load_model
import numpy as np
from tensorflow import keras
from PIL import Image

model = load_model('/content/BrainTumor_1.h5')

image_path = '/content/menigioma.jpg'   # Doctors said that was minigioma :(
new_image = Image.open(image_path)
new_image = new_image.resize((180, 180))
new_image = new_image.convert('RGB')  # Convert to RGB format
new_image = np.array(new_image) / 255.0

# Make a prediction
predicted_probabilities = model.predict(np.expand_dims(new_image, axis=0))

predicted_class = np.argmax(predicted_probabilities)

class_labels = ['giloma', 'meningioma', 'notumor', 'pituitary']

predicted_label = class_labels[predicted_class]

print(f"Predicted Class: {predicted_label}")
print(f"Class Probabilities: {predicted_probabilities}")
# Out:
# 1/1 [==============================] - 0s 101ms/step
# Predicted Class: meningioma
# Class Probabilities: [[1.5451302e-15 1.0000000e+00 7.8778356e-10 7.4754181e-14]]

# %%
from tensorflow.keras.models import load_model
import numpy as np
from tensorflow import keras
from PIL import Image

model = load_model('/content/BrainTumor_2.h5')

image_path = '/content/menigioma.jpg'   # Doctors said that was minigioma :(
new_image = Image.open(image_path)
new_image = new_image.resize((180, 180))
new_image = new_image.convert('RGB')  # Convert to RGB format
new_image = np.array(new_image) / 255.0

# Make a prediction
predicted_probabilities = model.predict(np.expand_dims(new_image, axis=0))

predicted_class = np.argmax(predicted_probabilities)

class_labels = ['giloma', 'meningioma', 'notumor', 'pituitary']

predicted_label = class_labels[predicted_class]

print(f"Predicted Class: {predicted_label}")
print(f"Class Probabilities: {predicted_probabilities}")
# Out:
# 1/1 [==============================] - 0s 102ms/step
# Predicted Class: meningioma
# Class Probabilities: [[1.5451302e-15 1.0000000e+00 7.8778356e-10 7.4754181e-14]]

# %% [markdown]
# ---

# %% [markdown]
# ![minigioma2.jpg](data:image/jpeg;base64,...)

# %%
from tensorflow.keras.models import load_model
import numpy as np
from tensorflow import keras
from PIL import Image

model = load_model('/content/BrainTumor_1.h5')

image_path = '/content/menigioma2.jpg'   # Doctors said that was minigioma :(
new_image = Image.open(image_path)
new_image = new_image.resize((180, 180))
new_image = new_image.convert('RGB')  # Convert to RGB format
new_image = np.array(new_image) / 255.0

# Make a prediction
predicted_probabilities = model.predict(np.expand_dims(new_image, axis=0))

predicted_class = np.argmax(predicted_probabilities)

class_labels = ['giloma', 'meningioma', 'notumor', 'pituitary']

predicted_label = class_labels[predicted_class]

print(f"Predicted Class: {predicted_label}")
print(f"Class Probabilities: {predicted_probabilities}")
# Out:
# 1/1 [==============================] - 0s 95ms/step
# Predicted Class: meningioma
# Class Probabilities: [[2.7310023e-12 9.9999797e-01 2.0473217e-06 2.7116524e-08]]

# %%
from tensorflow.keras.models import load_model
import numpy as np
from tensorflow import keras
from PIL import Image

model = load_model('/content/BrainTumor_2.h5')

image_path = '/content/menigioma2.jpg'   # Doctors said that was minigioma :(
new_image = Image.open(image_path)
new_image = new_image.resize((180, 180))
new_image = new_image.convert('RGB')  # Convert to RGB format
new_image = np.array(new_image) / 255.0

# Make a prediction
predicted_probabilities = model.predict(np.expand_dims(new_image, axis=0))

predicted_class = np.argmax(predicted_probabilities)

class_labels = ['giloma', 'meningioma', 'notumor', 'pituitary']

predicted_label = class_labels[predicted_class]

print(f"Predicted Class: {predicted_label}")
print(f"Class Probabilities: {predicted_probabilities}")
# Out:
# 1/1 [==============================] - 0s 129ms/step
# Predicted Class: meningioma
# Class Probabilities: [[2.7310023e-12 9.9999797e-01 2.0473217e-06 2.7116524e-08]]

# %% [markdown]
# #No_Tumor

# %% [markdown]
# ![notumor.jpg](data:image/jpeg;base64,...)

# %%
from tensorflow.keras.models import load_model
import numpy as np
from tensorflow import keras
from PIL import Image

model = load_model('/content/BrainTumor_1.h5')

image_path = '/content/notumor.jpg'   # Doctors said that was minigioma :(
new_image = Image.open(image_path)
new_image = new_image.resize((180, 180))
new_image = new_image.convert('RGB')  # Convert to RGB format
new_image = np.array(new_image) / 255.0

# Make a prediction
predicted_probabilities = model.predict(np.expand_dims(new_image, axis=0))

predicted_class = np.argmax(predicted_probabilities)

class_labels = ['giloma', 'meningioma', 'notumor', 'pituitary']

predicted_label = class_labels[predicted_class]

print(f"Predicted Class: {predicted_label}")
print(f"Class Probabilities: {predicted_probabilities}")
# Out:
# 1/1 [==============================] - 0s 102ms/step
# Predicted Class: notumor
# Class Probabilities: [[1.7063645e-33 1.9135260e-17 1.0000000e+00 3.1562643e-34]]

# %%
from tensorflow.keras.models import load_model
import numpy as np
from tensorflow import keras
from PIL import Image

model = load_model('/content/BrainTumor_2.h5')

image_path = '/content/notumor.jpg'    # Doctors said that was minigioma :(
new_image = Image.open(image_path)
new_image = new_image.resize((180, 180))
new_image = new_image.convert('RGB')  # Convert to RGB format
new_image = np.array(new_image) / 255.0

# Make a prediction
predicted_probabilities = model.predict(np.expand_dims(new_image, axis=0))

predicted_class = np.argmax(predicted_probabilities)

class_labels = ['giloma', 'meningioma', 'notumor', 'pituitary']

predicted_label = class_labels[predicted_class]

print(f"Predicted Class: {predicted_label}")
print(f"Class Probabilities: {predicted_probabilities}")
# Out:
# 1/1 [==============================] - 0s 102ms/step
# Predicted Class: notumor
# Class Probabilities: [[1.7063645e-33 1.9135260e-17 1.0000000e+00 3.1562643e-34]]

# %% [markdown]
# ---

# %% [markdown]
# ![notumor2.jpg](data:image/jpeg;base64,...)

# %%
from tensorflow.keras.models import load_model
import numpy as np
from tensorflow import keras
from PIL import Image

model = load_model('/content/BrainTumor_1.h5')

image_path = '/content/notumor2.jpg'   # Doctors said that was minigioma :(
new_image = Image.open(image_path)
new_image = new_image.resize((180, 180))
new_image = new_image.convert('RGB')  # Convert to RGB format
new_image = np.array(new_image) / 255.0

# Make a prediction
predicted_probabilities = model.predict(np.expand_dims(new_image, axis=0))

predicted_class = np.argmax(predicted_probabilities)

class_labels = ['giloma', 'meningioma', 'notumor', 'pituitary']

predicted_label = class_labels[predicted_class]

print(f"Predicted Class: {predicted_label}")
print(f"Class Probabilities: {predicted_probabilities}")
# Out:
# 1/1 [==============================] - 0s 97ms/step
# Predicted Class: notumor
# Class Probabilities: [[2.8200468e-04 5.7264790e-04 9.9904865e-01 9.6695541e-05]]

# %%
from tensorflow.keras.models import load_model
import numpy as np
from tensorflow import keras
from PIL import Image

model = load_model('/content/BrainTumor_2.h5')

image_path = '/content/notumor2.jpg'    # Doctors said that was minigioma :(
new_image = Image.open(image_path)
new_image = new_image.resize((180, 180))
new_image = new_image.convert('RGB')  # Convert to RGB format
new_image = np.array(new_image) / 255.0

# Make a prediction
predicted_probabilities = model.predict(np.expand_dims(new_image, axis=0))

predicted_class = np.argmax(predicted_probabilities)

class_labels = ['giloma', 'meningioma', 'notumor', 'pituitary']

predicted_label = class_labels[predicted_class]

print(f"Predicted Class: {predicted_label}")
print(f"Class Probabilities: {predicted_probabilities}")
# Out:
# 1/1 [==============================] - 0s 109ms/step
# Predicted Class: notumor
# Class Probabilities: [[2.8200468e-04 5.7264790e-04 9.9904865e-01 9.6695541e-05]]

# %% [markdown]
# # Pituitary

# %% [markdown]
# ![pituitary.jpg](data:image/jpeg;base64,...)

# %%
from tensorflow.keras.models import load_model
import numpy as np
from tensorflow import keras
from PIL import Image

model = load_model('/content/BrainTumor_1.h5')

image_path = '/content/pituitary.jpg'   # Doctors said that was minigioma :(
new_image = Image.open(image_path)
new_image = new_image.resize((180, 180))
new_image = new_image.convert('RGB')  # Convert to RGB format
new_image = np.array(new_image) / 255.0

# Make a prediction
predicted_probabilities = model.predict(np.expand_dims(new_image, axis=0))

predicted_class = np.argmax(predicted_probabilities)

class_labels = ['giloma', 'meningioma', 'notumor', 'pituitary']

predicted_label = class_labels[predicted_class]

print(f"Predicted Class: {predicted_label}")
print(f"Class Probabilities: {predicted_probabilities}")
# Out:
# 1/1 [==============================] - 0s 161ms/step
# Predicted Class: pituitary
# Class Probabilities: [[7.1498573e-05 2.4484817e-04 3.7726699e-04 9.9930644e-01]]

# %%
from tensorflow.keras.models import load_model
import numpy as np
from tensorflow import keras
from PIL import Image

model = load_model('/content/BrainTumor_2.h5')

image_path = '/content/pituitary.jpg'   # Doctors said that was minigioma :(
new_image = Image.open(image_path)
new_image = new_image.resize((180, 180))
new_image = new_image.convert('RGB')  # Convert to RGB format
new_image = np.array(new_image) / 255.0

# Make a prediction
predicted_probabilities = model.predict(np.expand_dims(new_image, axis=0))

predicted_class = np.argmax(predicted_probabilities)

class_labels = ['giloma', 'meningioma', 'notumor', 'pituitary']

predicted_label = class_labels[predicted_class]

print(f"Predicted Class: {predicted_label}")
print(f"Class Probabilities: {predicted_probabilities}")
# Out:
# 1/1 [==============================] - 0s 104ms/step
# Predicted Class: pituitary
# Class Probabilities: [[7.1498573e-05 2.4484817e-04 3.7726699e-04 9.9930644e-01]]

# %% [markdown]
# ---

# %% [markdown]
# ![pituitary2.jpg](data:image/jpeg;base64,...)

# %%
from tensorflow.keras.models import load_model
import numpy as np
from tensorflow import keras
from PIL import Image

model = load_model('/content/BrainTumor_1.h5')

image_path = '/content/pituitary2.jpg'   # Doctors said that was minigioma :(
new_image = Image.open(image_path)
new_image = new_image.resize((180, 180))
new_image = new_image.convert('RGB')  # Convert to RGB format
new_image = np.array(new_image) / 255.0

# Make a prediction
predicted_probabilities = model.predict(np.expand_dims(new_image, axis=0))

predicted_class = np.argmax(predicted_probabilities)

class_labels = ['giloma', 'meningioma', 'notumor', 'pituitary']

predicted_label = class_labels[predicted_class]

print(f"Predicted Class: {predicted_label}")
print(f"Class Probabilities: {predicted_probabilities}")
# Out:
# 1/1 [==============================] - 0s 109ms/step
# Predicted Class: pituitary
# Class Probabilities: [[3.4783548e-10 2.8341788e-06 3.1966979e-06 9.9999392e-01]]

# %%
from tensorflow.keras.models import load_model
import numpy as np
from tensorflow import keras
from PIL import Image

model = load_model('/content/BrainTumor_2.h5')

image_path = '/content/pituitary2.jpg'   # Doctors said that was minigioma :(
new_image = Image.open(image_path)
new_image = new_image.resize((180, 180))
new_image = new_image.convert('RGB')  # Convert to RGB format
new_image = np.array(new_image) / 255.0

# Make a prediction
predicted_probabilities = model.predict(np.expand_dims(new_image, axis=0))

predicted_class = np.argmax(predicted_probabilities)

class_labels = ['giloma', 'meningioma', 'notumor', 'pituitary']

predicted_label = class_labels[predicted_class]

print(f"Predicted Class: {predicted_label}")
print(f"Class Probabilities: {predicted_probabilities}")
# Out:
# 1/1 [==============================] - 0s 99ms/step
# Predicted Class: pituitary
# Class Probabilities: [[3.4783548e-10 2.8341788e-06 3.1966979e-06 9.9999392e-01]]
